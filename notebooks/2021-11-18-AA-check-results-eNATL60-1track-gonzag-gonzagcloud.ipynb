# %%
import xarray as xr
import sys
import glob
import numpy as nmp
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.mpl.ticker as cticker

# %matplotlib inline

# %%
ds_cloud=xr.open_dataset('../results/results_Altika-eNATL60-Region1-fma/result_00.nc')
ds_cloud
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 171)
# Coordinates:
#   * time            (time) float64 1.391e+18 1.391e+18 ... 1.391e+18 1.391e+18
# Data variables:
#     latitude        (time) float64 ...
#     longitude       (time) float64 ...
#     sossheig_np     (time) float64 ...
#     sossheig_bl     (time) float64 ...
#     sla_unfiltered  (time) float64 ...
#     distance        (time) float64 ...
#     time_counter    (time) datetime64[ns] ...
# Attributes:
#     about:    Created with Gonzag package => https://github.com/brodeau/gonzag

# %%
ds=xr.open_dataset('../results/results_Altika-eNATL60-Region1-fma/Altika-data-from-cloud-eNATL60-FMA-Region1-track0.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 171)
# Coordinates:
#   * time            (time) datetime64[ns] 2014-02-03T10:27:51.939834 ... 2014...
# Data variables:
#     sla_unfiltered  (time) float64 ...
#     lat             (time) float64 ...
#     lon             (time) float64 ...
# Attributes:
#     description:  cloud Altika data extracted for eNATL60 FMA month and Regio...

# %%
print(nmp.column_stack((ds_cloud.sla_unfiltered.values,ds.sla_unfiltered.values)))
# Out:
# [[ 0.119  0.037]
#  [ 0.118  0.059]
#  [ 0.077  0.087]
#  [ 0.065  0.087]
#  [ 0.08   0.091]
#  [ 0.1    0.105]
#  [ 0.108  0.055]
#  [ 0.034  0.077]
#  [ 0.044  0.109]
#  [ 0.009  0.127]
#  [ 0.015  0.123]
#  [ 0.027  0.15 ]
#  [ 0.024  0.118]
#  [ 0.028  0.129]
#  [ 0.018  0.127]
#  [ 0.034  0.122]
#  [ 0.071  0.114]
#  [ 0.083  0.1  ]
#  [ 0.068  0.093]
#  [ 0.051  0.104]
#  [ 0.067  0.061]
#  [ 0.086  0.025]
#  [ 0.072  0.026]
#  [ 0.09   0.023]
#  [ 0.07   0.014]
#  [ 0.116 -0.012]
#  [ 0.118 -0.028]
#  [ 0.1   -0.027]
#  [ 0.115 -0.033]
#  [ 0.111 -0.057]
#  [ 0.1   -0.056]
#  [ 0.083 -0.075]
#  [ 0.078 -0.069]
#  [ 0.101 -0.091]
#  [ 0.105 -0.097]
#  [ 0.091 -0.108]
#  [ 0.104 -0.113]
#  [ 0.097 -0.121]
#  [ 0.096 -0.132]
#  [ 0.083 -0.129]
#  [ 0.067 -0.145]
#  [ 0.083 -0.137]
#  [ 0.112 -0.121]
#  [ 0.11  -0.136]
#  [ 0.091 -0.137]
#  [ 0.09  -0.116]
#  [ 0.077 -0.101]
#  [ 0.061 -0.093]
#  [ 0.074 -0.076]
#  [ 0.049 -0.08 ]
#  [ 0.061 -0.058]
#  [ 0.092 -0.062]
# ...

# %%
plt.plot(ds_cloud.sla_unfiltered.values,label='cloud')
plt.plot(ds.sla_unfiltered.values,label='nocloud')
plt.legend()
