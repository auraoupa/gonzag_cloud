# %% [markdown]
# # Comparison of spectrum between GIGATL outputs and Alitka Satellite
#
# Requisites :
#  - git clone https://github.com/auraoupa/gonzag_cloud

# %%
import sys,os
from os import getenv
import warnings
warnings.filterwarnings("ignore")

# %%
GONZAG_DIR = '/home/jovyan/gonzag_cloud' ; 
sys.path.append(GONZAG_DIR)
import gonzag as gz

# %% [markdown]
# ## Params

# %% [markdown]
# For the model

# %%
model = 'eNATL60'
region = '1'
season = 'fma'
surf='surface_hourly'
name_mod = model+'-Region'+region+'-'+season
name_ssh_mod = 'sossheig'
name_lsm_mod = 'tmask' 
name_lat_mod = 'lat'
name_lon_mod = 'lon'
name_time_mod = 'time_counter'
l_griddist = False
period_mod = ['2010-02-01','2010-04-30']

# %% [markdown]
# For altimetry data

# %%
name_sat= 'Altika'
tag_sat_catalog = 'al'
name_ssh_sat='sla_unfiltered'
name_time_sat='time'
period_sat = ['2014-02-01','2014-04-30'] #should cover the same period of a different year if needed

# %% [markdown]
# ## Data

# %%
import xarray as xr
import intake
import gcsfs

gcs = gcsfs.GCSFileSystem(requester_pays=True)

cat = intake.open_catalog('../../SWOT-AdAC/catalog.yaml')
dsmod1 = cat[model](region=region,depth=surf, season=season).to_dask()

# %%
dsmod1
# Out:
# <xarray.Dataset>
# Dimensions:        (time_counter: 2136, x: 611, y: 763)
# Coordinates: (12/15)
#     depth          (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1t            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1u            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e1v            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     e2f            (y, x) float64 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     ...             ...
#     lat            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     lon            (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lat        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     nav_lon        (y, x) float32 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     time_centered  (time_counter) datetime64[ns] dask.array<chunksize=(72,), meta=np.ndarray>
#   * time_counter   (time_counter) datetime64[ns] 2010-02-01T00:30:00 ... 2010...
# Dimensions without coordinates: x, y
# Data variables: (12/13)
#     fmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     qt_oce         (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     somecrty       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sometauy       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sosaline       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sossheig       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     ...             ...
#     sowaflup       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozocrtx       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     sozotaux       (time_counter, y, x) float32 dask.array<chunksize=(72, 763, 611), meta=np.ndarray>
#     tmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     umask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>
#     vmask          (y, x) int8 dask.array<chunksize=(763, 611), meta=np.ndarray>

# %%
if model == 'GIGATL':#get rid of 29th of february (2010 = leap year)
    import numpy as nmp
    from gonzag.io import GetTimeVector
    from gonzag.utils import scan_idx
    rvt = GetTimeVector( dsmod1, name_time_mod, lquiet=True )
    (rtu1,rtu2)=nmp.array(['2000-02-29T00:00:00','2000-03-01T00:00:00'], dtype='datetime64')
    jt1, jt2 = scan_idx( rvt, rtu1, rtu2 )
    dsmod=dsmod1.drop_isel(time=nmp.arange(jt1,jt2+1,1))
else:
    dsmod=dsmod1

# %%
from intake import open_catalog
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/altimetry.yaml")
dssat  = cat[tag_sat_catalog].to_dask()

# %%
dssat
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 34340107)
# Coordinates:
#     latitude        (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     longitude       (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#   * time            (time) datetime64[ns] 2013-03-14T05:44:50.445185 ... 2015...
# Data variables:
#     cycle           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     dac             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     lwe             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     mdt             (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     ocean_tide      (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_filtered    (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     sla_unfiltered  (time) float64 dask.array<chunksize=(34340107,), meta=np.ndarray>
#     track           (time) int16 dask.array<chunksize=(34340107,), meta=np.ndarray>
# Attributes: (12/24)
#     Conventions:               CF-1.6
#     Metadata_Conventions:      Unidata Dataset Discovery v1.0
#     cdm_data_type:             Swath
#     comment:                   Sea surface height measured by altimeters refe...
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     creator_email:             servicedesk.cmems@mercator-ocean.eu
#     ...                        ...
#     software_version:          6.2_DUACS_DT2018_baseline
#     source:                    Altika measurements
#     ssalto_duacs_comment:      The reference mission used for the altimeter i...
#     standard_name_vocabulary:  NetCDF Climate and Forecast (CF) Metadata Conv...
#     summary:                   SSALTO/DUACS Delayed-Time Level-3 sea surface ...
#     title:                     DT Altika Global Ocean Along track SSALTO/DUAC...

# %% [markdown]
# ## Model and Satellite objects

# %%
ModelGrid = gz.ModGrid( dsmod, period_mod, name_lon_mod, name_lat_mod , name_time_mod, dsmod, name_lsm_mod, distorded_grid=False )
# Out:
#  *** what we use to define model land-sea mask:
#     => "tmask" in dataset
#
#  *** Skipping computation of angle distortion of the model grid! ("-D" option not invoked)...
#
#  *** About model gridded (source) domain:
#      * shape =  (763, 611)
#      * horizontal resolution:  0.016657295  degrees or  1.8507920147292316  km
#      * Is this a global domain w.r.t longitude:  False
#        ==> this is a regional domain
#        ==> working in the [0:360] frame...
#      * lon_min, lon_max =  281.97 292.16
#      * lat_min, lat_max =  30.0 39.99
#      * should we pay attention to possible STRONG local distorsion in the grid:  False
#      * number of time records of interest for the interpolation to come:  2112
#        ==> time record dates: 2010-02-01 to 2010-04-30, included

# %%
SatelliteTrack = gz.SatTrack( dssat, period_sat, name_time_sat, name_ssh_sat, domain_bounds=ModelGrid.domain_bounds, l_0_360=ModelGrid.l360 )
# Out:
#  *** [SatTrack()] Analyzing the time vector in dataset ...
#
#  *** About satellite track (target) domain:
#      * number of time records of interest for the interpolation to come:  10225
#        ==> time record indices: 14883510 to 19033581, included
#
#        separated in 86 tracks

# %% [markdown]
# ## Process the tracks in parallel (results are saved in separate netcdf files)

# %%
if not os.path.exists('../results/results_'+name_sat+'-'+name_mod):
        os.makedirs('../results/results_'+name_sat+'-'+name_mod)

# %%
def process_one_track(track):
    tt = "{:02d}".format(track)
    Solution0 = gz.Model2SatTrack( ModelGrid, name_ssh_mod, SatelliteTrack, name_ssh_sat, track )
    c1     = 'Model SSH interpolated in space (' ; c2=') and time on satellite track'
    vvar   = [ 'latitude', 'longitude', name_ssh_mod+'_np'   , name_ssh_mod+'_bl' , name_ssh_sat          , 'distance'                            ]
    vunits = [ 'deg.N'   , 'deg.E'    ,          'm'         ,     'm'            ,    'm'                ,    'km'                               ]
    vlongN = [ 'Latitude', 'Longitude', c1+'nearest-point'+c2,  c1+'bilinear'+c2  , 'Input satellite data', 'Cumulated distance from first point' ]
    from gonzag.config import rmissval
    iw = gz.io.SaveTimeSeries( Solution0.time, \
                             nmp.array( [Solution0.lat, Solution0.lon, Solution0.ssh_mod_np,
                                         Solution0.ssh_mod, Solution0.ssh_sat, Solution0.distance] ), \
                             vvar, '../results/results_'+name_sat+'-'+name_mod+'/result_'+str(tt)+'.nc', time_units='',\
                             vunits=vunits, vlnm=vlongN, missing_val=rmissval )
    return Solution0

# %%
import dask
import sys
import dask.bag as db
import numpy as nmp

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:37979' processes=8 threads=64, memory=251.90 GiB>

# %%
# %%time
b = db.from_sequence(nmp.arange(len(SatelliteTrack.index_tracks)), npartitions=64)
results = b.map(lambda x: process_one_track(x))
final = results.compute()
# Out:
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# asyncio.exceptions.CancelledError
# CPU times: user 29min 8s, sys: 3min 9s, total: 32min 18s
# Wall time: 2h 5min 34s
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_80.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_66.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_81.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_38.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_39.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_52.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_67.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_22.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_53.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_23.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_12.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_74.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_75.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_30.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_06.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_44.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_13.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_31.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_07.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_45.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_24.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_04.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_54.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_82.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_83.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_55.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_68.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_05.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_25.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_69.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_60.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_32.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_76.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_00.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_14.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_46.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_33.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_01.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_47.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_61.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_77.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_15.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_34.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_78.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_79.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_16.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_62.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_48.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_02.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_35.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_03.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_49.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_63.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_17.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_72.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_42.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_58.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_43.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_59.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_10.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_73.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_28.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_11.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_29.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_84.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_56.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_40.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_85.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_70.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_71.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_57.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_41.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_26.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_27.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_20.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_50.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_18.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_51.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_36.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_64.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_08.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_19.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_21.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_09.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_65.nc" successfully written!
#
#  *** "../results/results_Altika-eNATL60-Region1-fma/result_37.nc" successfully written!
# /srv/conda/envs/notebook/lib/python3.8/contextlib.py:120: UserWarning: Creating scratch directories is taking a surprisingly long time. This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# /srv/conda/envs/notebook/lib/python3.8/contextlib.py:120: UserWarning: Creating scratch directories is taking a surprisingly long time. This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
